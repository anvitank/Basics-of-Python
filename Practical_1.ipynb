# %% [markdown]
# <a href="https://colab.research.google.com/github/anvitank/Basics-of-Python/blob/main/Practical_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Name: Anvi Singh Tank
# ##PRN: 25070123019
# ##Batch: ENTC A1
# ##Expt 1

# %%
# First Program
print("I am Learning Python")
# Out:
# I am Learning Python

# %%
print('I am at Symbiosis')
# Out:
# I am at Symbiosis

# %%
a="Hello"
print(a)
# Out:
# Hello

# %%
#Many Statements
print("Hello"); print("How are you?"); print("bye")
# Out:
# Hello
# How are you?
# bye

# %%
print("Anvi"); print("Tank")
# Out:
# Anvi
# Tank

# %%
print("Anvi", end=" ")
print("Tank")
# Out:
# Anvi Tank

# %%
# Print Numbers
print(3)
b=10
print(b)
# Out:
# 3
# 10

# %%
# Variables
x= 7
y= "heyy"
print(x)
print(y)
# Out:
# 7
# heyy

# %%
# Case Sensitive
a=8
A="Rohan"
print(a)
print(A)
# Out:
# 8
# Rohan

# %%
# Multiple Values to Multiple Variables
a, b, c = "Apple", "Samsung", "Lenovo"
print(a); print(b); print(c)
# Out:
# Apple
# Samsung
# Lenovo

# %%
a= 7
b= 5
print("Addition=",a+b)
print("Subtraction=",a-b)
print("Multiplication=",a*b)
print("Division=",a/b)
print("Modulus=",a%b)
# Out:
# Addition= 12
# Subtraction= 2
# Multiplication= 35
# Division= 1.4
# Modulus= 2

# %%
# Understanding Data Types
x = 10
y = 3.14
z = "Python"
flag = True
c= 3+2j

print(type(x))
print(type(y))
print(type(z))
print(type(flag))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
name= input("Enter your name:")
print("hello", name)
# Out:
# Enter your name:Anvi
# hello Anvi

# %%
#Simple Calculator
a=int(input("enter a no."))
b=int(input("enter another no."))

func=input("Enter Function to be performed")

if func=="Add":
  print(a+b)
if func=="Subtract":
  print(a-b)
if func=="Multiply":
  print(a*b)
if func=="Division":
  print(a/b)
# Out:
# enter a no.6
# enter another no.7
# Enter Function to be performedMultiply
# 42

# %%
#Total And Avg Marks
mat=int(input("Enter Maths Marks:"))
eng=int(input("Enter English Marks:"))
phy=int(input("Enter Physics Marks:"))
bio=int(input("Enter Bio Marks:"))
chem=int(input("Enter Chemistry Marks:"))

total = mat + eng + phy + bio + chem
avg= total / 5

print("The total marks are", total)
print("The average marks are", avg)
# Out:
# Enter Maths Marks:95
# Enter English Marks:98
# Enter Physics Marks:96
# Enter Bio Marks:95
# Enter Chemistry Marks:97
# The total marks are 481
# The average marks are 96.2

# %%
#Area of rectangle
l=int(input("Enter Length:"))
b=int(input("Enter Breadth:"))
area=l*b
print("The area of rectangle is",area)
# Out:
# Enter Length:5
# Enter Breadth:8
# The area of rectangle is 40

# %%
#Area of Circle
r=int(input("Enter Radius:"))
area= 3.14 * r**2
print("The area of circle is", area)
# Out:
# Enter Radius:6
# The area of circle is 113.04

# %%
#Appending Arrays
A=(3,4,5)+(6,7,8)
print(A)
# Out:
# (3, 4, 5, 6, 7, 8)
